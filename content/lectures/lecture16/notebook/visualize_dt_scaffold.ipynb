# %% [markdown]
# <a href="https://colab.research.google.com/github/lovecrushfamily/2021-CS109A/blob/master/content/lectures/lecture16/notebook/visualize_dt_scaffold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Title :
# Exercise: Visualizing a Decision Tree
#
# ## Description :
# The aim of this exercise is to visualize the decision tree that is created when performing Decision Tree Classification or Regression. The tree will look similar to the one given below.
#
# <img src="https://github.com/lovecrushfamily/2021-CS109A/blob/master/content/lectures/lecture16/fig/fig1.png?raw=1" style="width: 500px;">
#
# ## Data Description:
# We are trying to predict the winner of the 2016 Presidential election (Trump vs. Clinton) in each county in the US.  To do this, we will consider several predictors including  minority: the percentage of residents that are minorities and bachelor: the percentage of resident adults with a bachelor's degree (or higher).
#
# ## Instructions:
#
# - Read the datafile `county_election_train.csv` into a Pandas data frame.
# - Create the response variable based on the columns `trump` and `clinton`.
# - Initialize a Decision Tree classifier of depth 3 and fit on the training data.
# - Visualise the Decision Tree.
#
# ## Hints:
#
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html" target="_blank">sklearn.DecisionTreeClassifier()</a>Generates a Logistic Regression classifier.
#
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier.fit" target="_blank">classifier.fit()</a>Build a decision tree classifier from the training set (X, y).
#
# <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html" target="_blank">plt.scatter()</a>A scatter plot of y vs. x with varying marker size and/or color.
#
# <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html" target="_blank">plt.xlabel()</a>Set the label for the x-axis.
#
# <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html" target="_blank">plt.ylabel()</a>Set the label for the y-axis.
#
# <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html" target="_blank">plt.legend()</a>Place a legend on the Axes.
#
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html" target="_blank">tree.plot_tree()</a>Plot a decision tree.
#
# **Note: This exercise is auto-graded and you can try multiple attempts. **

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 20)
plt.rcParams["figure.figsize"] = (12,8)

# %%
# Read the datafile "county_election_train.csv" as a Pandas dataframe
elect_train = pd.read_csv("https://raw.githubusercontent.com/lovecrushfamily/2021-CS109A/refs/heads/master/content/lectures/lecture16/data/county_election_train.csv")

# Read the datafile "county_election_test.csv" as a Pandas dataframe
elect_test = pd.read_csv("https://raw.githubusercontent.com/lovecrushfamily/2021-CS109A/refs/heads/master/content/lectures/lecture16/data/county_election_test.csv")

# Take a quick look at the dataframe
elect_train.head()
# Out:
#      state  fipscode          county  population  hispanic  minority  female  unemployed  income  \
# 0  Alabama      1001  Autauga County       50756     2.842    22.733  51.475         5.2   54366
# 1  Alabama      1003  Baldwin County      179878     4.550    12.934  51.261         5.5   49626
# 2  Alabama      1007     Bibb County       21587     2.409    23.930  46.110         6.6   39546
# 3  Alabama      1009   Blount County       58345     8.954     4.229  50.592         5.4   45567
# 4  Alabama      1011  Bullock County       10985     7.526    72.831  45.241         7.8   26580
#
#    nodegree  bachelor  inactivity  obesity  density  cancer   trump  clinton  votergap
# 0      13.8      21.9        28.6     34.1     91.8   186.5  73.436   23.957    49.479
# 1      11.0      28.6        22.3     27.4    114.6   229.4  77.351   19.565    57.786
# 2      22.1      10.2        33.9     40.3     36.8   230.3  76.966   21.422    55.544
# 3      21.9      12.3        28.0     34.6     88.9   205.3  89.852    8.470    81.382
# 4      34.5      14.1        31.7     43.0     17.5   211.2  24.229   75.090   -50.862

# %%
elect_train.dropna(inplace=True)

# %%
### edTest(test_response) ###

# Creating the response variable

# Set all the rows in the train data where "trump" value is more than "clinton" as 1
y_train = elect_train[elect_train["trump"] > elect_train["clinton"]]

# Set all the rows in the test data where "trump" value is more than "clinton" as 1
y_test = elect_test[elect_test["trump"] > elect_test["clinton"]]

# %%
# Plot "minority" vs "bachelor" as a scatter plot
# Set colours blue for Trump and green for Clinton
plt.scatter(elect_train[elect_train["trump"] > elect_train["clinton"]]["minority"], elect_train[elect_train["trump"] > elect_train["clinton"]]["bachelor"], color="blue", label="Trump")
plt.scatter(elect_train[elect_train["trump"] < elect_train["clinton"]]["minority"], elect_train[elect_train["trump"] < elect_train["clinton"]]["bachelor"], color="green", label="Clinton")
plt.xlabel("minority")
plt.ylabel("bachelor")
plt.legend()

# Your code here

# %%
# Initialize a Decision Tree classifier of depth 3 and choose
# splitting criteria to be the gini
dtree = DecisionTreeClassifier(max_depth=3, criterion="gini")

# Fit the classifier on the train data
# but only use the minority column as the predictor variable
dtree.fit(elect_train[["minority"]], y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8b0131b20c67> in <cell line: 0>()
#       5 # Fit the classifier on the train data
#       6 # but only use the minority column as the predictor variable
# ----> 7 dtree.fit(elect_train[["minority"]], y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1022         """
#    1023
# -> 1024         super()._fit(
#    1025             X,
#    1026             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     292
#     293         if is_classification:
# --> 294             check_classification_targets(y)
#     295             y = np.copy(y)
#     296
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     212         Target values.
#     213     """
# --> 214     y_type = type_of_target(y, input_name="y")
#     215     if y_type not in [
#     216         "binary",
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/multiclass.py in type_of_target(y, input_name, raise_unknown)
#     331         raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
#     332
# --> 333     if is_multilabel(y):
#     334         return "multilabel-indicator"
#     335
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/multiclass.py in is_multilabel(y)
#     192         )
#     193     else:
# --> 194         labels = cached_unique(y, xp=xp)
#     195
#     196         return labels.shape[0] < 3 and (
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_unique.py in cached_unique(xp, *ys)
#     103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_unique.py in <genexpr>(.0)
#     103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_unique.py in _cached_unique(y, xp)
#      76         pass
#      77     xp, _ = get_namespace(y, xp=xp)
# ---> 78     return xp.unique_values(y)
#      79
#      80
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_array_api.py in unique_values(self, x)
#     414
#     415     def unique_values(self, x):
# --> 416         return numpy.unique(x)
#     417
#     418     def unique_all(self, x):
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_arraysetops_impl.py in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     287     ar = np.asanyarray(ar)
#     288     if axis is None:
# --> 289         ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     290                         equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     291         return _unpack_tuple(ret)
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_arraysetops_impl.py in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     354         aux = ar[perm]
#     355     else:
# --> 356         ar.sort()
#     357         aux = ar
#     358     mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
elect_train[["minority"]]
# Out:
#       minority
# 0       22.733
# 1       12.934
# 2       23.930
# 3        4.229
# 4       72.831
# ...        ...
# 2615     5.846
# 2616     4.778
# 2617     4.601
# 2618     5.259
# 2619     4.769
#
# [2580 rows x 1 columns]

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 20)
plt.rcParams["figure.figsize"] = (12,8)

# Read the datafile "county_election_train.csv" as a Pandas dataframe
elect_train = pd.read_csv("https://raw.githubusercontent.com/lovecrushfamily/2021-CS109A/refs/heads/master/content/lectures/lecture16/data/county_election_train.csv")

# Read the datafile "county_election_test.csv" as a Pandas dataframe
elect_test = pd.read_csv("https://raw.githubusercontent.com/lovecrushfamily/2021-CS109A/refs/heads/master/content/lectures/lecture16/data/county_election_test.csv")

# Take a quick look at the dataframe
elect_train.head()

elect_train.dropna(inplace=True)

### edTest(test_response) ###

# Creating the response variable

# Create a new column 'election_outcome' which is 1 if Trump won and 0 if Clinton won
elect_train['election_outcome'] = (elect_train["trump"] > elect_train["clinton"]).astype(int)
elect_test['election_outcome'] = (elect_test["trump"] > elect_test["clinton"]).astype(int)

# Assign the 'election_outcome' column to y_train and y_test
y_train = elect_train['election_outcome']
y_test = elect_test['election_outcome']


# Plot "minority" vs "bachelor" as a scatter plot
# Set colours blue for Trump and green for Clinton
plt.scatter(elect_train[elect_train["trump"] > elect_train["clinton"]]["minority"], elect_train[elect_train["trump"] > elect_train["clinton"]]["bachelor"], color="blue", label="Trump")
plt.scatter(elect_train[elect_train["trump"] < elect_train["clinton"]]["minority"], elect_train[elect_train["trump"] < elect_train["clinton"]]["bachelor"], color="green", label="Clinton")
plt.xlabel("minority")
plt.ylabel("bachelor")
plt.legend()

# Your code here


# Initialize a Decision Tree classifier of depth 3 and choose
# splitting criteria to be the gini
dtree = DecisionTreeClassifier(max_depth=3, criterion="gini")

# Fit the classifier on the train data
# but only use the minority column as the predictor variable
dtree.fit(elect_train[["minority"]], y_train)


# Code to set the size of the plot
plt.figure(figsize=(30,20))

# Plot the Decision Tree trained above with parameters filled as True
# You need to pass the fitted tree object and other optional parameters
tree.plot_tree(dtree, filled=True, feature_names=["minority"], class_names=["Clinton", "Trump"])


plt.show();
